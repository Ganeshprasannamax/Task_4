# %% [markdown]
# <a href="https://colab.research.google.com/github/Ganeshprasannamax/Guvi_Assement-2/blob/main/Assessment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv('college_1.csv')
df2 = pd.read_csv('college_2.csv')

# %%
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df1.shape
# Out:
# (84, 7)

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df1.columns
# Out:
# Index(['Name', 'python', 'mysql', 'Previous Geekions', 'CodeKata Score',
#        'Department', 'Rising'],
#       dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               84 non-null     object
#  1   python             84 non-null     float64
#  2   mysql              84 non-null     float64
#  3   Previous Geekions  84 non-null     int64
#  4   CodeKata Score     84 non-null     int64
#  5   Department         84 non-null     object
#  6   Rising             84 non-null     int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 4.7+ KB

# %%
df1.isnull().sum()
# Out:
# Name                 0
# python               0
# mysql                0
# Previous Geekions    0
# CodeKata Score       0
# Department           0
# Rising               0
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# Name                 0
# python               0
# mysql                0
# Previous Geekions    0
# CodeKata Score       0
# Department           0
# Rising               0
# dtype: int64

# %%
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df2.shape
# Out:
# (35, 9)

# %%
df2.columns
# Out:
# Index(['Name', 'python', 'python_en', 'mysql', 'computational_thinking',
#        'Previous Geekions', 'CodeKata Score', 'Department', 'Rising'],
#       dtype='object')

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    35 non-null     object
#  1   python                  35 non-null     int64
#  2   python_en               35 non-null     int64
#  3   mysql                   35 non-null     int64
#  4   computational_thinking  35 non-null     int64
#  5   Previous Geekions       35 non-null     int64
#  6   CodeKata Score          35 non-null     int64
#  7   Department              35 non-null     object
#  8   Rising                  35 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 2.6+ KB

# %%
df2.isnull().sum()
# Out:
# Name                      0
# python                    0
# python_en                 0
# mysql                     0
# computational_thinking    0
# Previous Geekions         0
# CodeKata Score            0
# Department                0
# Rising                    0
# dtype: int64

# %%
df2.describe()
# Out:
#            python   python_en       mysql  computational_thinking  \
# count   35.000000   35.000000   35.000000               35.000000
# mean     8.657143   29.657143   13.657143                2.200000
# std     25.795511   30.582524   22.002597                7.015948
# min     -1.000000   -1.000000   -1.000000               -1.000000
# 25%     -1.000000    0.000000    0.000000                0.000000
# 50%     -1.000000   20.000000    0.000000                0.000000
# 75%     -1.000000   52.000000   24.000000                0.000000
# max    100.000000  100.000000  100.000000               39.000000
#
#        Previous Geekions  CodeKata Score       Rising
# count          35.000000       35.000000    35.000000
# mean         6093.142857     6801.428571   708.285714
# std          3650.436534     3765.281134   836.429687
# min             0.000000        0.000000     0.000000
# 25%          4035.000000     4630.000000     0.000000
# ...

# %%
dataframe = df1.append(df2,ignore_index = True)
dataframe
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %%
Final = dataframe.fillna(0)
Final
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %%
Final.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        0.0                     0.0
# 1  Computer Science and Engineering       0        0.0                     0.0
# 2  Computer Science and Engineering       0        0.0                     0.0
# 3  Computer Science and Engineering       0        0.0                     0.0
# 4  Computer Science and Engineering       0        0.0                     0.0

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Exceeded_expectation = Final[Final['CodeKata Score']>15000]
Exceeded_expectation.to_csv('Exceeded_expectations.csv')

# %%
Reached_expectation = Final[(Final['CodeKata Score']>10000) & (Final['CodeKata Score']<15000)]
Reached_expectation.to_csv('Reached_expectations.csv')

# %%
Needs_Improvement = Final[(Final['CodeKata Score']>7000) & (Final['CodeKata Score']<10000)]
Needs_Improvement.to_csv('Needs_Improvement.csv')

# %%
Unsatisfactory = Final[Final['CodeKata Score']<7000]
Unsatisfactory.to_csv('Unsatisfactory.csv')

# %%
Final.shape
# Out:
# (119, 9)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
col = ['Previous Geekions','CodeKata Score']
Final[col].mean()
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
Final
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
python = Final[Final['python'] == 100]

# %%
python.shape
# Out:
# (41, 9)

# %%
print('No of students completed the my_sql course is:' , python.shape[0])
print('overall students:' , Final.shape[0])
a = (python.shape[0]/Final.shape[0])*100
print('percentage of students completed the mysql assignment is:',round(a))
# Out:
# No of students completed the my_sql course is: 41
# overall students: 119
# percentage of students completed the mysql assignment is: 34

# %%
mysql = Final[Final['mysql'] == 100]

# %%
mysql.shape
# Out:
# (14, 9)

# %%
print('No of students completed the my_sql course is:' ,mysql.shape[0])
print('overall students:' , Final.shape[0])
b = (mysql.shape[0]/Final.shape[0])*100
print('percentage of students completed the mysql assignment is:',round(b))
# Out:
# No of students completed the my_sql course is: 14
# overall students: 119
# percentage of students completed the mysql assignment is: 12

# %%
python_en_comp = Final[Final['python_en'] == 100]

# %%
python_en_comp.shape
# Out:
# (2, 9)

# %%
print('No of students completed the my_sql course is:' , python_en_comp.shape[0])
print('overall students:' , Final.shape[0])
c = (python_en_comp.shape[0]/Final.shape[0])*100
print('percentage of students completed the mysql assignment is:',round(c))
# Out:
# No of students completed the my_sql course is: 2
# overall students: 119
# percentage of students completed the mysql assignment is: 2

# %%
computational_thinking_comp = Final[Final['computational_thinking'] == 100]

# %%
computational_thinking_comp.shape
# Out:
# (0, 9)

# %%
print('No of students completed the my_sql course is:' , computational_thinking_comp.shape[0])
print('overall students:' , Final.shape[0])
d = (computational_thinking_comp.shape[0]/Final.shape[0])*100
print('percentage of students completed the mysql assignment is:',round(d))
# Out:
# No of students completed the my_sql course is: 0
# overall students: 119
# percentage of students completed the mysql assignment is: 0

# %%
Avg = Final.loc[(Final['python']==100)|(Final['mysql']==100)|(Final['python_en']==100)|(Final['computational_thinking']==100)]

# %%
Avg.shape
# Out:
# (46, 9)

# %%
a = (Avg.shape[0]/Final.shape[0])*100

# %%
print('Average completion of python course or my_sql or pyrhon english or computational thinking is:' ,a)
# Out:
# Average completion of python course or my_sql or pyrhon english or computational thinking is: 38.655462184873954

# %%
Final.head(10)
# Out:
#                    Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0             A.Dharani    82.0   20.0              24500           24500
# 1           V.JEEVITHA     82.0   20.0              21740           21740
# 2           HEMAVATHI.R   100.0  100.0              19680           19680
# 3           Mugunthan S   100.0   47.0              10610           10610
# 4           Sathammai.S   100.0    8.0               8980            8980
# 5          NIVEESHWAR S   100.0    0.0               8200            8200
# 6         KALAIARASAN K    85.0   47.0               7750            7880
# 7  MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 8            J.SUGANTHI    27.0   50.0               5860            5860
# 9          thamizhpaana    29.0    0.0               5500            5500
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        0.0
# ...

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
Final['performance'] = Final['CodeKata Score'] - Final['Previous Geekions']
Final
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        0.0
# ...

# %%
star_of_the_week = Final.nlargest(3,['performance'])
star_of_the_week
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 86         Computer Science and Engineering    2000       55.0
# 102        Computer Science and Engineering    2000       -1.0
#
#      computational_thinking  performance
# 92                      0.0         3140
# 86                      6.0         2000
# 102                     0.0         2000

# %%
print('Top 3 candidates performed well in that particular week are:')
for i in star_of_the_week['Name']:
  print(i)
# Out:
# Top 3 candidates performed well in that particular week are:
# shifak N
# Ganesh Ramkumar R
# Narasimhan Y L

# %%
 Highest_geekions = Final.nlargest(3,['CodeKata Score'])
 Highest_geekions
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        0.0
# 1  Computer Science and Engineering       0        0.0
# 2  Computer Science and Engineering       0        0.0
#
#    computational_thinking  performance
# 0                     0.0            0
# 1                     0.0            0
# 2                     0.0            0

# %%
print('Top 3 candidates are highest geekions of the week :')
for i in Highest_geekions['Name']:
  print(i)
# Out:
# Top 3 candidates are highest geekions of the week :
# A.Dharani
# V.JEEVITHA
# HEMAVATHI.R

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
Highest_geekions = Final.nlargest(3,['CodeKata Score'])
Highest_geekions
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  \
# 0  Computer Science and Engineering       0        0.0
# 1  Computer Science and Engineering       0        0.0
# 2  Computer Science and Engineering       0        0.0
#
#    computational_thinking  performance
# 0                     0.0            0
# 1                     0.0            0
# 2                     0.0            0

# %%
print('Top 3 candidates are highest geekions of the week :')
for i in Highest_geekions['Name']:
  print(i)
# Out:
# Top 3 candidates are highest geekions of the week :
# A.Dharani
# V.JEEVITHA
# HEMAVATHI.R

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
Final['Department'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
cse = Final[Final['Department'] == 'Computer Science and Engineering']
cse
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0            A.Dharani    82.0   20.0              24500           24500
# 1          V.JEEVITHA     82.0   20.0              21740           21740
# 2          HEMAVATHI.R   100.0  100.0              19680           19680
# 3          Mugunthan S   100.0   47.0              10610           10610
# 4          Sathammai.S   100.0    8.0               8980            8980
# ..                 ...     ...    ...                ...             ...
# 111  Vimalesh Fernando    -1.0    0.0               4170            4170
# 112      M.Karthikeyan    -1.0    4.0               4020            4020
# 114      praveen raj j    24.0    0.0               2380            2380
# 117               XY Z    -1.0   -1.0                  0               0
# 118          Hariharan    -1.0   -1.0                  0               0
#
#                            Department  Rising  python_en  \
# ...

# %%
cse['CodeKata Score'].mean()
# Out:
# 5079.761904761905

# %%
ece = Final[Final['Department'] == 'Electronics and Communication Engineering']
ece
# Out:
#                            Name  python   mysql  Previous Geekions  \
# 6                 KALAIARASAN K    85.0   47.00               7750
# 8                    J.SUGANTHI    27.0   50.00               5860
# 10              Iyappan Samiraj    50.0   24.00               5400
# 14              Melvin Dukles.R    56.0   20.00               4800
# 17                  v.vithyasri   100.0   12.00               4370
# 18           Abirami Anbazhagan   100.0    0.00               4320
# 21                 kamalishwari    32.0   20.00               3665
# 25                    Tpavithra   100.0   24.00               3200
# 27                     shankari    87.5   20.00               3000
# 32                   SarumathiR    16.0   35.00               2240
# 35                     Barath D    74.0    4.00               1910
# 39                      vignesh    85.0    0.00               1740
# 42                    ABIRAMI.S    82.0    0.00               1580
# ...

# %%
ece['CodeKata Score'].mean()
# Out:
# 2777.8205128205127

# %%
eee = Final[Final['Department'] == 'Electronics and Electrical Engineering']
eee
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 64       k.parvathi   100.0  100.0                260             260
# 71      m.keerthana    97.5    0.0                120             120
# 72       Subhashini   100.0    4.0                120             120
# 74  J.Bhuvaneshwari   100.0   20.0                100             100
# 75         santhosh    82.0   12.0                 60              60
# 77       J.JAYANTHI   100.0  100.0                 40              40
# 78     vikneshwaran   100.0    4.0                 40              40
# 79     KarthikeyanS    45.0    0.0                  0               0
# 80         BARATH.P    29.0    0.0                  0               0
# 81    N.Ajith kumar    82.0    0.0                  0               0
# 82     mohamed nabi     0.0    0.0                  0               0
# 83   yaser ahamed.A     0.0   27.0                  0               0
# ...

# %%
eee['CodeKata Score'].mean()
# Out:
# 3164.705882352941

# %%
import matplotlib.pyplot as plt
import numpy as np

labels = ['cse','ece','eee']
X = np.array([5079.761904761905,2777.8205128205127,3164.705882352941])

plt.pie(X,labels = labels, startangle=90,autopct='%2f%%',radius=2)
plt.title('Department wise codekata performance')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
cse
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0            A.Dharani    82.0   20.0              24500           24500
# 1          V.JEEVITHA     82.0   20.0              21740           21740
# 2          HEMAVATHI.R   100.0  100.0              19680           19680
# 3          Mugunthan S   100.0   47.0              10610           10610
# 4          Sathammai.S   100.0    8.0               8980            8980
# ..                 ...     ...    ...                ...             ...
# 111  Vimalesh Fernando    -1.0    0.0               4170            4170
# 112      M.Karthikeyan    -1.0    4.0               4020            4020
# 114      praveen raj j    24.0    0.0               2380            2380
# 117               XY Z    -1.0   -1.0                  0               0
# 118          Hariharan    -1.0   -1.0                  0               0
#
#                            Department  Rising  python_en  \
# ...

# %%
cse_toppers = cse.nlargest(5,['CodeKata Score'])
cse_toppers
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0           A.Dharani    82.0   20.0              24500           24500
# 1         V.JEEVITHA     82.0   20.0              21740           21740
# 2         HEMAVATHI.R   100.0  100.0              19680           19680
# 85            Chandru     0.0    0.0              14150           14490
# 86  Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                           Department  Rising  python_en  \
# 0   Computer Science and Engineering       0        0.0
# 1   Computer Science and Engineering       0        0.0
# 2   Computer Science and Engineering       0        0.0
# 85  Computer Science and Engineering     340       20.0
# 86  Computer Science and Engineering    2000       55.0
#
#     computational_thinking  performance
# 0                      0.0            0
# 1                      0.0            0
# 2                      0.0            0
# ...

# %%
plt.barh(cse_toppers['Name'],cse_toppers['CodeKata Score'])
plt.title('Computer Science and Engineering toppers')
plt.xlabel('CodeKata Score')
plt.ylabel('Name')
plt.show()

# %%
ece_toppers = ece.nlargest(5,['CodeKata Score'])
ece_toppers
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 87   Bodipudi Harini    -1.0   35.0              10040           10040
# 91         Gowtham R    -1.0    4.0               8650            8650
# 6      KALAIARASAN K    85.0   47.0               7750            7880
# 98         Praneetha    -1.0  100.0               7170            7730
# 100          Guhan S    -1.0   35.0               7310            7630
#
#                                     Department  Rising  python_en  \
# 87   Electronics and Communication Engineering       0        0.0
# 91   Electronics and Communication Engineering       0       60.0
# 6    Electronics and Communication Engineering     130        0.0
# 98   Electronics and Communication Engineering     560       23.0
# 100  Electronics and Communication Engineering     320       72.0
#
#      computational_thinking  performance
# 87                     -1.0            0
# 91                      6.0            0
# ...

# %%
plt.barh(ece_toppers['Name'],ece_toppers['CodeKata Score'])
plt.title('Electronics and Communication Engineering toppers')
plt.xlabel('CodeKata Score')
plt.ylabel('Name')
plt.show()

# %%
plt.barh(ece_toppers['Name'],ece_toppers['CodeKata Score'])
plt.title('Electronics and Communication Engineering toppers')
plt.xlabel('CodeKata Score')
plt.ylabel('Name')
plt.show()

# %%
eee_toppers = eee.nlargest(5,['CodeKata Score'])
eee_toppers
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 84  ASHOK KUMAR K   100.0   31.0              19400           19400
# 88      VIINU V P    -1.0   24.0               9150            9150
# 92       shifak N    58.0    0.0               5180            8320
# 93        Balaji     -1.0   20.0               6170            8160
# 96       JPradhap   100.0    0.0               7340            8030
#
#                                 Department  Rising  python_en  \
# 84  Electronics and Electrical Engineering       0        0.0
# 88  Electronics and Electrical Engineering       0      100.0
# 92  Electronics and Electrical Engineering    3140        0.0
# 93  Electronics and Electrical Engineering    1990      100.0
# 96  Electronics and Electrical Engineering     690        0.0
#
#     computational_thinking  performance
# 84                     9.0            0
# 88                    -1.0            0
# 92                     0.0         3140
# ...

# %%
c
# Out:
# 1.680672268907563

# %%
plt.barh(eee_toppers['Name'],eee_toppers['CodeKata Score'])
plt.title('Electronics and Electrical Engineering toppers')
plt.xlabel('CodeKata Score')
plt.ylabel('Name')
plt.show()
